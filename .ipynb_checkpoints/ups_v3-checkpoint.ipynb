# %% [markdown]
# Custom Dimensional Weight Divisor : 257
#
# The incentives stated above are valid from July 27, 2019 to June 25, 2022.
#
# Instructions
#
# https://billing.ups.com/home
#
#     click on my invoices
#
#     export data to table to create the helpful one
#
#     download documents to create the detailed one
#
#
# https://docs.google.com/document/d/1X_ptuq2UsNBSR3m1nW-qWsye34lB7soxKTAYMYcmDEM/edit?usp=sharing
#
# https://www.ups.com/assets/resources/media/en_US/SurePost_Terms.pdf -- Surepost terms

# %%
import os
import glob
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', 250)
pd.set_option('display.max_columns', 50)

# %%
header_list = ["Version","Recipient Number","Account Number","Account Country/Territory","Invoice Date","Invoice Number",
               "Invoice Type Code","Invoice Type Detail Code","Account Tax ID","Invoice Currency Code","Invoice Amount",
               "Transaction Date","Pickup Record Number","Lead Shipment Number","World Ease Number",
               "Shipment Reference Number 1","Shipment Reference Number 2","Bill Option Code","Package Quantity",
               "Oversize Quantity","Tracking Number","Package Reference Number 1","Package Reference Number 2",
               "Package Reference Number 3","Package Reference Number 4","Package Reference Number 5","Entered Weight",
               "Entered Weight Unit of Measure","Billed Weight","Billed Weight Unit of Measure","Container Type",
               "Billed Weight Type","Package Dimensions","Zone","Charge Category Code","Charge Category Detail Code",
               "Charge Source","Type Code 1","Type Detail Code 1","Type Detail Value 1","Type Code 2","Type Detail Code 2",
               "Type Detail Value 2","Charge Classification Code","Charge Description Code","Charge Description",
               "Charged Unit Quantity","Basis Currency Code","Basis Value","Tax Indicator","Transaction Currency Code",
               "Incentive Amount","Net Amount","Miscellaneous Currency Code","Miscellaneous Incentive Amount",
               "Miscellaneous Net Amount","Alternate Invoicing Currency Code","Alternate Invoice Amount",
               "Invoice Exchange Rate","Tax Variance Amount","Currency Variance Amount","Invoice Level Charge",
               "Invoice Due Date","Alternate Invoice Number","Store Number","Customer Reference Number","Sender Name",
               "Sender Company Name","Sender Address Line 1","Sender Address Line 2","Sender City","Sender State",
               "Sender Postal","Sender Country/Territory","Receiver Name","Receiver Company Name","Receiver Address Line 1",
               "Receiver Address Line 2","Receiver City","Receiver State","Receiver Postal","Receiver Country/Territory",
               "Third Party Name","Third Party Company Name","Third Party Address Line 1","Third Party Address Line 2",
               "Third Party City","Third Party State","Third Party Postal","Third party Country/Territory","Sold To Name",
               "Sold To Company Name","Sold To Address Line 1","Sold To Address Line 2","Sold To City","Sold To State",
               "Sold To Postal","Sold to Country/Territory","Miscellaneous Address Qual 1","Miscellaneous Address 1 Name",
               "Miscellaneous Address 1 Company Name","Miscellaneous Address 1 Address Line 1",
               "Miscellaneous Address 1 Address Line 2","Miscellaneous Address 1 City","Miscellaneous Address 1 State",
               "Miscellaneous Address 1 Postal","Miscellaneous address 1 Country/Territory","Miscellaneous Address Qual 2",
               "Miscellaneous Address 2 Name","Miscellaneous Address 2 Company Name","Miscellaneous Address 2 Address Line 1",
               "Miscellaneous Address 2 Address Line 2","Miscellaneous Address 2 City","Miscellaneous Address 2 State",
               "Miscellaneous Address 2 Postal","Miscellaneous address 2 Country/Territory","Shipment Date",
               "Shipment Export Date","Shipment Import Date","Entry Date","Direct Shipment Date","Shipment Delivery Date",
               "Shipment Release Date","Cycle Date","EFT Date","Validation Date","Entry Port","Entry Number","Export Place",
               "Shipment Value Amount","Shipment Description","Entered Currency Code","Customs Number","Exchange Rate",
               "Master Air Waybill Number","EPU","Entry Type","CPC Code","Line Item Number","Goods Description","Entered Value",
               "Duty Amount","Weight","Unit of Measure","Item Quantity","Item Quantity Unit of Measure","Import Tax ID",
               "Declaration Number","Carrier Name/Clinical Trial Identification Number/SDS ID ","CCCD Number","Cycle Number",
               "Foreign Trade Reference Number","Job Number","Transport Mode","Tax Type","Tariff Code","Tariff Rate",
               "Tariff Treatment Number","Contact Name","Class Number","Document Type","Office Number","Document Number",
               "Duty Value","Total Value for Duty","Excise Tax Amount","Excise Tax Rate","GST Amount","GST Rate",
               "Order In Council","Origin Country/Territory","SIMA Access","Tax Value","Total Customs Amount",
               "Miscellaneous Line 1","Miscellaneous Line 2","Miscellaneous Line 3","Miscellaneous Line 4",
               "Miscellaneous Line 5","Payor Role Code","Miscellaneous Line 7","Miscellaneous Line 8","Miscellaneous Line 9",
               "Miscellaneous Line 10","Miscellaneous Line 11","Duty Rate","VAT Basis Amount","VAT Amount","VAT Rate",
               "Other Basis Amount","Other Amount","Other Rate","Other Customs Number Indicator","Other Customs Number",
               "Customs Office Name","Package Dimension Unit Of Measure","Original Shipment Package Quantity","Corrected Zone",
               "Tax Law Article Number","Tax Law Article Basis Amount","Original tracking number","Scale weight quantity",
               "Scale Weight Unit of Measure","Raw dimension unit of measure","Raw dimension length","BOL # 1","BOL # 2",
               "BOL # 3","BOL # 4","BOL # 5","PO # 1","PO # 2","PO # 3","PO # 4","PO # 5","PO # 6","PO # 7","PO # 8",
               "PO # 9","PO # 10","NMFC","Detail Class","Freight Sequence Number","Declared Freight Class","EORI Number",
               "Detail Keyed Dim","Detail Keyed Unit of Measure","Detail Keyed Billed Dimension","Detail Keyed Billed Unit of Measure",
               "Original Service Description","Promo Discount Applied Indicator","Promo Discount Alias","SDS Match Level Cd",
               "SDS RDR Date","SDS Delivery Date","SDS Error Code","Place Holder 46","Place Holder 47","Place Holder 48",
               "SCC Scale Weight","Place Holder 50","Place Holder 51","Place Holder 52","Place Holder 53","Place Holder 54",
               "Place Holder 55","Place Holder 56","Place Holder 57","Place Holder 58","Place Holder 59"]

# %%
extension = 'csv'
all_filenames = [i for i in glob.glob('Invoice_*.{}'.format(extension))]
all_filenames
# Out:
# ['Invoice_000000R4R346012_010122.csv',
#  'Invoice_000000R4R346022_010822.csv',
#  'Invoice_000000R4R346491_120421.csv',
#  'Invoice_000000R4R346501_121121.csv',
#  'Invoice_000000R4R346511_121821.csv',
#  'Invoice_000000R4R346521_122521.csv']

# %%
df_master = pd.DataFrame()
for file in all_filenames:
    df = pd.read_csv(file, names=header_list)
    df['Detail Keyed Dim'] = df['Detail Keyed Dim'].bfill()  
    df_master = df_master.append(df)

# %%
print(df_master.shape)
df_master.head()
df = df_master
# Out:
# (12797, 250)

# %%
for col in df.columns:
    if len(df[col].unique()) == 1:
        df.drop(col,inplace=True,axis=1)
        
df_detailed = df

# %%
all_filenames = [i for i in glob.glob('000000R4R346*.{}'.format(extension))]
all_filenames
# Out:
# ['000000R4R346012-SHIPMENT_2022-01-06_114725.csv',
#  '000000R4R346022-SHIPMENT_2022-01-10_92042.csv',
#  '000000R4R346491-SHIPMENT_2021-12-28_22154.csv',
#  '000000R4R346501-SHIPMENT_2021-12-28_22228.csv',
#  '000000R4R346511-SHIPMENT_2021-12-28_22218.csv',
#  '000000R4R346521-SHIPMENT_2021-12-28_22208.csv']

# %%
df_condenced = pd.DataFrame()
for file in all_filenames:
    df = pd.read_csv(file)  
    df_condenced = df_condenced.append(df)
  
df_condenced = df_condenced[df_condenced.columns.drop(["Ref No 2", 'Type', 'System'])]

# %%
def convert_currency(val):
    """
    Convert the string number value to a float
     - Remove $
     - Remove commas
     - Convert to float type
    """
    new_val = val.replace(',','').replace('$', '')
    return float(new_val)

df_condenced['Net Charge'] = df_condenced['Net Charge'].apply(convert_currency)

# %%
inspect = df_detailed.groupby(by='Tracking Number', dropna=True).max()

# df_clean = pd.merge(df_condenced,inspect[['Billed Weight', 'Package Quantity', 'Zone', 'Receiver Company Name', 'Receiver Address Line 1',
#                                       'Receiver Address Line 2','Receiver City', 'Receiver State', 'Receiver Postal']],
#                                     on ='Tracking Number', how='inner')

df_clean = pd.merge(df_condenced,inspect[['Billed Weight', 'Package Quantity', 'Zone','Receiver City',
                                          'Receiver State', 'Receiver Postal']], on ='Tracking Number', how='inner')
# Out:
# C:\Users\evan\AppData\Local\Temp/ipykernel_5644/3486596341.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   inspect = df_detailed.groupby(by='Tracking Number', dropna=True).max()

# %%
df_clean = pd.merge(df_clean,df_detailed[['Tracking Number', 'Detail Keyed Dim']], 
                                    on ='Tracking Number', how='inner')

# %%
df_clean.drop_duplicates(keep='first', inplace=True, ignore_index=True)

# %%
# clean data 
df_clean['Published Charge'] = df_clean['Published Charge'].apply(convert_currency)
df_clean['Incentive Charge'] = df_clean['Incentive Charge'].apply(convert_currency)
df_clean['Transaction Date'] = pd.to_datetime(df_clean['Transaction Date'])
df_clean['Receiver Postal'] = df_clean['Receiver Postal'].astype(int).astype(str).str.zfill(5)
df_clean['Ref No 1'] = df_clean['Ref No 1'].str.split("-",1).str[0]

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3883 entries, 0 to 3882
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Tracking Number   3883 non-null   object
#  1   Transaction Date  3883 non-null   datetime64[ns]
#  2   Service Code      3883 non-null   object
#  3   Published Charge  3883 non-null   float64
#  4   Incentive Charge  3883 non-null   float64
#  5   Net Charge        3883 non-null   float64
#  6   Ref No 1          3097 non-null   object
#  7   Billed Weight     3883 non-null   float64
#  8   Package Quantity  3883 non-null   int64
#  9   Zone              3883 non-null   float64
#  10  Receiver City     3883 non-null   object
#  11  Receiver State    3883 non-null   object
#  12  Receiver Postal   3883 non-null   object
#  13  Detail Keyed Dim  3877 non-null   object
# dtypes: datetime64[ns](1), float64(5), int64(1), object(7)
# memory usage: 424.8+ KB

# %%
# Total Cost Per Shipment w/ adjustments 
df_tot_cost = pd.DataFrame()
df_tot_cost['Total Cost'] = df_detailed[['Tracking Number', 'Net Amount']].groupby(by = 'Tracking Number').sum()
df_tot_cost.rename_axis("Tracking Number")
# Out:
#                     Total Cost
# Tracking Number
# 1Z986E610266212958       77.21
# 1Z986E610266875368       77.21
# 1ZA61V200391184732       56.28
# 1ZR4R3460393093680       10.10
# 1ZR4R3460393966657        9.72
# ...                        ...
# 1ZR4R346YW99986733       13.98
# 1ZR4R346YW99986788       10.56
# 1ZR4R346YW99988311       12.84
# 1ZR4R346YW99998515       16.44
# 1ZR4R346YW99999907       11.98
#
# [3873 rows x 1 columns]

# %%
df_clean = pd.merge(df_clean,df_tot_cost['Total Cost'], 
                                    on ='Tracking Number', how='inner')

# %%
df_clean['Adjustment'] = round((df_clean['Total Cost'] - df_clean['Net Charge']), 2)

# %%
# view adjustments 

df_adj = df_clean[df_clean['Adjustment'] != 0]
#df_adj.drop_duplicates(keep='first', inplace=True, ignore_index=True)
df_adj.sort_values(by=['Transaction Date'], ascending=False)
# Out:
#          Tracking Number Transaction Date                    Service Code  \
# 758   1ZR4R346YW99463913       2022-01-04  UPS SurePost - 1 LB or Greater
# 759   1ZR4R346YW99463913       2022-01-04  UPS SurePost - 1 LB or Greater
# 371   1ZR4R346YW92275344       2022-01-03  UPS SurePost - 1 LB or Greater
# 679   1ZR4R346YW97739183       2022-01-03  UPS SurePost - 1 LB or Greater
# 254   1ZR4R346YW90599945       2021-12-29  UPS SurePost - 1 LB or Greater
# 533   1ZR4R346YW94667202       2021-12-29  UPS SurePost - 1 LB or Greater
# 375   1ZR4R346YW92365167       2021-12-28  UPS SurePost - 1 LB or Greater
# 633   1ZR4R346YW96750224       2021-12-28  UPS SurePost - 1 LB or Greater
# 3693  1ZR4R346YW97439480       2021-12-20  UPS SurePost - 1 LB or Greater
# 3676  1ZR4R346YW97153734       2021-12-20  UPS SurePost - 1 LB or Greater
# 3675  1ZR4R346YW97153734       2021-12-20  UPS SurePost - 1 LB or Greater
# 3694  1ZR4R346YW97439480       2021-12-20  UPS SurePost - 1 LB or Greater
# 3530  1ZR4R346YW95021808       2021-12-17  UPS SurePost - 1 LB or Greater
# 3519  1ZR4R346YW94602790       2021-12-17  UPS SurePost - 1 LB or Greater
# 3401  1ZR4R346YW91107778       2021-12-16  UPS SurePost - 1 LB or Greater
# 3402  1ZR4R346YW91107778       2021-12-16  UPS SurePost - 1 LB or Greater
# 2964  1ZR4R346YW94063971       2021-12-14  UPS SurePost - 1 LB or Greater
# 2963  1ZR4R346YW94063971       2021-12-14  UPS SurePost - 1 LB or Greater
# 2724  1ZR4R346YW90094981       2021-12-14  UPS SurePost - 1 LB or Greater
# 2978  1ZR4R346YW94312200       2021-12-13  UPS SurePost - 1 LB or Greater
# 2808  1ZR4R346YW91535109       2021-12-13  UPS SurePost - 1 LB or Greater
# 3187  1ZR4R346YW97857242       2021-12-13  UPS SurePost - 1 LB or Greater
# 3072  1ZR4R346YW96138780       2021-12-13  UPS SurePost - 1 LB or Greater
# 2807  1ZR4R346YW91535109       2021-12-13  UPS SurePost - 1 LB or Greater
# 3031  1ZR4R346YW95532499       2021-12-13  UPS SurePost - 1 LB or Greater
# 2854  1ZR4R346YW92290649       2021-12-10  UPS SurePost - 1 LB or Greater
# 2895  1ZR4R346YW92834776       2021-12-10  UPS SurePost - 1 LB or Greater
# 2894  1ZR4R346YW92834776       2021-12-10  UPS SurePost - 1 LB or Greater
# 2853  1ZR4R346YW92290649       2021-12-10  UPS SurePost - 1 LB or Greater
# 2985  1ZR4R346YW94504404       2021-12-08  UPS SurePost - 1 LB or Greater
# 2094  1ZR4R346YW92500457       2021-12-08  UPS SurePost - 1 LB or Greater
# 1885  1ZR4R346YW90049119       2021-12-08  UPS SurePost - 1 LB or Greater
# 2053  1ZR4R346YW92045575       2021-12-07  UPS SurePost - 1 LB or Greater
# 2363  1ZR4R346YW95663777       2021-12-06  UPS SurePost - 1 LB or Greater
# 2581  1ZR4R346YW98469393       2021-12-06  UPS SurePost - 1 LB or Greater
# 2582  1ZR4R346YW98469393       2021-12-06  UPS SurePost - 1 LB or Greater
# 2346  1ZR4R346YW95334944       2021-12-06  UPS SurePost - 1 LB or Greater
# 3665  1ZR4R346YW97054752       2021-12-03  UPS SurePost - 1 LB or Greater
# 3664  1ZR4R346YW97054752       2021-12-03  UPS SurePost - 1 LB or Greater
# 2583  1ZR4R346YW98475519       2021-12-03  UPS SurePost - 1 LB or Greater
# 2064  1ZR4R346YW92163492       2021-12-02  UPS SurePost - 1 LB or Greater
# 2065  1ZR4R346YW92163492       2021-12-02  UPS SurePost - 1 LB or Greater
# 2106  1ZR4R346YW92610052       2021-12-02  UPS SurePost - 1 LB or Greater
# 1728  1ZR4R346YW98652041       2021-11-30  UPS SurePost - 1 LB or Greater
# 1727  1ZR4R346YW98652041       2021-11-30  UPS SurePost - 1 LB or Greater
# 854   1ZR4R346YW90509256       2021-11-29  UPS SurePost - 1 LB or Greater
# 2505  1ZR4R346YW97545981       2021-11-29  UPS SurePost - 1 LB or Greater
# 2602  1ZR4R346YW98710255       2021-11-29  UPS SurePost - 1 LB or Greater
# 2408  1ZR4R346YW96207919       2021-11-29  UPS SurePost - 1 LB or Greater
# 2407  1ZR4R346YW96207919       2021-11-29  UPS SurePost - 1 LB or Greater
# 2198  1ZR4R346YW93792891       2021-11-29  UPS SurePost - 1 LB or Greater
# 2197  1ZR4R346YW93792891       2021-11-29  UPS SurePost - 1 LB or Greater
# 1828  1ZR4R346YW99504100       2021-11-26  UPS SurePost - 1 LB or Greater
# 1243  1ZR4R346YW94279711       2021-11-26  UPS SurePost - 1 LB or Greater
# 1242  1ZR4R346YW94279711       2021-11-26  UPS SurePost - 1 LB or Greater
# 1827  1ZR4R346YW99504100       2021-11-26  UPS SurePost - 1 LB or Greater
# 1578  1ZR4R346YW97239811       2021-11-26  UPS SurePost - 1 LB or Greater
# 1267  1ZR4R346YW94482438       2021-11-23  UPS SurePost - 1 LB or Greater
#
#       Published Charge  Incentive Charge  Net Charge       Ref No 1  \
# 758              15.86             -3.17       12.69            NaN
# 759              15.86             -3.17       12.69            NaN
# 371              17.08             -3.42       13.66            NaN
# 679              17.70             -3.54       14.16            NaN
# 254              18.46             -3.69       14.77            NaN
# 533              18.46             -3.69       14.77            NaN
# 375              17.54             -3.51       14.03            NaN
# 633              22.23             -3.68       18.55            NaN
# 3693             20.41             -3.43       16.98        3134562
# 3676             18.66             -3.21       15.45        3134609
# 3675             18.66             -3.21       15.45        3134609
# 3694             20.41             -3.43       16.98        3134562
# 3530             17.48             -3.50       13.98        3134375
# 3519             14.91             -2.98       11.93        3134341
# 3401             17.14             -3.43       13.71        3134301
# 3402             17.14             -3.43       13.71        3134301
# 2964             16.05             -3.21       12.84        3134023
# 2963             16.05             -3.21       12.84        3134023
# 2724             21.20             -3.59       17.61        3134079
# 2978             17.93             -3.59       14.34        3133820
# 2808             20.41             -3.43       16.98        3133767
# 3187             18.66             -3.21       15.45        3133584
# 3072             16.05             -3.21       12.84        3133603
# 2807             20.41             -3.43       16.98        3133767
# 3031             16.05             -3.21       12.84        3133674
# 2854             16.62             -3.33       13.29        3133471
# 2895             17.48             -3.50       13.98        3133505
# 2894             17.48             -3.50       13.98        3133505
# 2853             16.62             -3.33       13.29        3133471
# 2985             17.48             -3.50       13.98        3133333
# 2094             17.52             -2.98       14.54        3133320
# 1885             16.05             -3.21       12.84        3133293
# 2053             16.05             -3.21       12.84        3133230
# 2363             18.66             -3.21       15.45        3132928
# 2581             17.48             -3.50       13.98        3132923
# 2582             17.48             -3.50       13.98        3132923
# 2346             18.66             -3.21       15.45        3133068
# 3665             16.05             -3.21       12.84        3132891
# 3664             16.05             -3.21       12.84        3132891
# 2583             17.48             -3.50       13.98        3132887
# 2064             18.05             -2.96       15.09        3132755
# 2065             18.05             -2.96       15.09        3132755
# 2106             14.72             -2.43       12.29  8863360781756
# 1728             16.05             -3.21       12.84        3132436
# 1727             16.05             -3.21       12.84        3132436
# 854              16.05             -3.21       12.84        3131532
# 2505             16.62             -3.33       13.29        3131558
# 2602             17.48             -3.50       13.98        3132015
# 2408             21.99             -3.87       18.12        3132009
# 2407             21.99             -3.87       18.12        3132009
# 2198             17.48             -3.50       13.98        3131591
# 2197             17.48             -3.50       13.98        3131591
# 1828             17.93             -3.59       14.34        3131321
# 1243             17.48             -3.50       13.98        3131433
# 1242             17.48             -3.50       13.98        3131433
# 1827             17.93             -3.59       14.34        3131321
# 1578             21.20             -3.59       17.61         732622
# 1267             16.62             -3.33       13.29        3131092
#
#       Billed Weight  Package Quantity  Zone    Receiver City Receiver State  \
# 758            12.0                 1   4.0         Chandler             AZ
# 759            12.0                 1   4.0         Chandler             AZ
# 371            12.0                 1   5.0           Conroe             TX
# 679            10.0                 1   6.0    Sandy Springs             GA
# 254            11.0                 1   7.0     Delray Beach             FL
# 533             7.0                 1   7.0         Brighton             MA
# 375            11.0                 1   6.0         Marietta             OH
# 633            11.0                 1   7.0           Naples             FL
# 3693           16.0                 1   5.0        La Moille             IL
# 3676           11.0                 1   5.0     Grand Rapids             MN
# 3675           11.0                 1   5.0     Grand Rapids             MN
# 3694           16.0                 1   5.0        La Moille             IL
# 3530           13.0                 1   7.0         Abingdon             MD
# 3519           13.0                 1   4.0      Sioux Falls             SD
# 3401           17.0                 1   5.0       Starkville             MS
# 3402           17.0                 1   5.0       Starkville             MS
# 2964           12.0                 1   5.0            Edina             MN
# 2963           12.0                 1   5.0            Edina             MN
# 2724           17.0                 1   6.0         Sapphire             NC
# 2978           15.0                 1   6.0        Lancaster             OH
# 2808           17.0                 1   5.0         Sherrard             IL
# 3187           11.0                 1   5.0         Brainerd             MN
# 3072           11.0                 1   5.0           Corona             CA
# 2807           17.0                 1   5.0         Sherrard             IL
# 3031            6.0                 1   5.0           Austin             TX
# 2854           12.0                 1   6.0       Cincinnati             OH
# 2895           12.0                 1   7.0          Shelton             CT
# 2894           12.0                 1   7.0          Shelton             CT
# 2853           12.0                 1   6.0       Cincinnati             OH
# 2985           11.0                 1   7.0          Sanford             FL
# 2094           10.0                 1   4.0             Iola             KS
# 1885           12.0                 1   5.0       Richardson             TX
# 2053           10.0                 1   5.0           Conway             AR
# 2363           11.0                 1   5.0          Oronoco             MN
# 2581           11.0                 1   7.0         Palm Bay             FL
# 2582           11.0                 1   7.0         Palm Bay             FL
# 2346            7.0                 1   5.0         Mayfield             KY
# 3665           13.0                 1   5.0        Hillsboro             OR
# 3664           13.0                 1   5.0        Hillsboro             OR
# 2583           11.0                 1   7.0         Palm Bay             FL
# 2064            6.0                 1   4.0          Antlers             OK
# 2065            6.0                 1   4.0          Antlers             OK
# 2106            9.0                 1   5.0            Kelso             WA
# 1728           12.0                 1   5.0      Friendswood             TX
# 1727           12.0                 1   5.0      Friendswood             TX
# 854            11.0                 1   5.0    Redondo Beach             CA
# 2505           10.0                 1   6.0          Acworth             GA
# 2602           12.0                 1   7.0  West Palm Beach             FL
# 2408           17.0                 1   7.0           Milton             DE
# 2407           17.0                 1   7.0           Milton             DE
# 2198           11.0                 1   7.0          Orlando             FL
# 2197           11.0                 1   7.0          Orlando             FL
# 1828           17.0                 1   6.0       Fort Wayne             IN
# 1243           10.0                 1   7.0         Franklin             MA
# 1242           10.0                 1   7.0         Franklin             MA
# 1827           17.0                 1   6.0       Fort Wayne             IN
# 1578           15.0                 1   6.0     Harbor Beach             MI
# 1267           11.0                 1   6.0           Lorain             OH
#
#      Receiver Postal  Detail Keyed Dim  Total Cost  Adjustment
# 758            85249  15.0x 15.0x  6.0       22.11        9.42
# 759            85249               NaN       22.11        9.42
# 371            77304  15.0x 15.0x  6.0       23.87       10.21
# 679            30328  15.0x 15.0x  6.0       24.31       10.15
# 254            33446  15.0x 15.0x  6.0       29.12       14.35
# 533            02135  15.0x 15.0x  6.0       15.15        0.38
# 375            45750  15.0x 15.0x  6.0       24.74       10.71
# 633            34120  15.0x 15.0x  6.0       32.90       14.35
# 3693           61330  15.0x 15.0x 10.0       27.82       10.84
# 3676           55744  15.0x 15.0x 10.0       24.64        9.19
# 3675           55744  15.0x 15.0x  6.0       24.64        9.19
# 3694           61330               NaN       27.82       10.84
# 3530           21009  15.0x 15.0x  6.0       30.60       16.62
# 3519           57107  15.0x 15.0x  6.0       20.92        8.99
# 3401           39759  15.0x 15.0x 10.0       25.24       11.53
# 3402           39759  15.0x 15.0x  6.0       25.24       11.53
# 2964           55435               NaN       22.33        9.49
# 2963           55435  15.0x 15.0x  6.0       22.33        9.49
# 2724           28774  15.0x 15.0x 10.0       33.21       15.60
# 2978           43130  15.0x 15.0x 10.0       27.84       13.50
# 2808           61281  15.0x 15.0x  6.0       28.51       11.53
# 3187           56401  15.0x 15.0x  6.0       24.64        9.19
# 3072           92881  15.0x 15.0x  6.0       22.03        9.19
# 2807           61281  15.0x 15.0x 10.0       28.51       11.53
# 3031           78752  15.0x 15.0x  6.0       16.24        3.40
# 2854           45249  15.0x 15.0x 10.0       24.16       10.87
# 2895           06484  15.0x 15.0x 10.0       28.57       14.59
# 2894           06484  15.0x 15.0x  6.0       28.57       14.59
# 2853           45249  15.0x 15.0x  6.0       24.16       10.87
# 2985           32773  15.0x 15.0x  6.0       27.49       13.51
# 2094           66749  15.0x 15.0x  6.0       22.69        8.15
# 1885           75080  15.0x 15.0x  6.0       22.33        9.49
# 2053           72032  15.0x 15.0x  6.0       21.93        9.09
# 2363           55960  15.0x 15.0x  6.0       24.64        9.19
# 2581           32907  15.0x 15.0x  6.0       27.49       13.51
# 2582           32907               NaN       27.49       13.51
# 2346           42066  15.0x 15.0x  6.0       15.83        0.38
# 3665           97123               NaN       22.75        9.91
# 3664           97123  15.0x 15.0x  6.0       22.75        9.91
# 2583           32907  15.0x 15.0x  6.0       27.49       13.51
# 2064           74523  15.0x 15.0x  6.0       32.30       17.21
# 2065           74523  14.0x 14.0x  6.0       32.30       17.21
# 2106           98626  15.0x 15.0x  6.0       16.32        4.03
# 1728           77546               NaN       22.33        9.49
# 1727           77546  15.0x 15.0x  6.0       22.33        9.49
# 854            90278  15.0x 15.0x  6.0       22.03        9.19
# 2505           30101  15.0x 15.0x  6.0       22.62        9.33
# 2602           33405  15.0x 15.0x  6.0       28.57       14.59
# 2408           19968  15.0x 15.0x  6.0       39.69       21.57
# 2407           19968  15.0x 15.0x 10.0       39.69       21.57
# 2198           32811  15.0x 15.0x 10.0       27.49       13.51
# 2197           32811  15.0x 15.0x  6.0       27.49       13.51
# 1828           46835  15.0x 15.0x  6.0       29.94       15.60
# 1243           02038  15.0x 15.0x 10.0       25.41       11.43
# 1242           02038  15.0x 15.0x  6.0       25.41       11.43
# 1827           46835  15.0x 15.0x 10.0       29.94       15.60
# 1578           48441  15.0x 15.0x 10.0       31.11       13.50
# 1267           44052  15.0x 15.0x  6.0       23.35       10.06

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

figure(figsize=(12, 10), dpi=80);

sns.scatterplot(x='Billed Weight',
               y = 'Total Cost',
               hue = 'Detail Keyed Dim',
               data = df_clean);

plt.legend(loc='best', bbox_to_anchor=(.7, 0., .6, 1));

# %%
figure(figsize=(12, 4), dpi=80);
ax = sns.regplot(x="Billed Weight", y="Total Cost", data=df_clean)#, x_jitter=.3)

# %%
df_clean.to_csv("expore.csv", header=True, index=False)
